# %% [markdown]
# # SENG 207- PROJECT 1
#
# ## NAME: DELORES NKRUMAH
# ## ID:10956674
# ## DEPARTMENT: BIOMEDICAL ENGINEERING

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns

# %%
book = pd.read_csv('data.csv')

# %%
book
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
book_1= book.fillna(book.mean())
book_1
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density        pH  \
# ...

# %%
book_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# ### REASON FOR USING THE REPLACE NULL VALUES USING MEAN
# --------
# ##### The mean is the most frequent used measure of central tendency. Since the data set give is missing at most three values from each column and the mean gives the average of the data set values it is best to replace null values with the mean because it give the best accuracy.

# %%
book_1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Length: 1601, dtype: bool

# %%
book_final=book_1.drop_duplicates()
book_final
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density        pH  \
# ...

# %%
book_final.duplicated().sum()
# Out:
# 0

# %%
book_info= book_final.iloc[:,1:].describe()
book_info
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1601.000000       1601.000000  1601.000000     1601.000000
# mean        8.319875          0.527742     0.271175        2.538445
# std         1.739495          0.178981     0.194684        1.409138
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1601.000000          1601.000000           1601.000000  1601.000000
# mean      0.087487            15.886875             46.520000     0.996746
# std       0.047032            10.455218             32.967416     0.001887
# ...

# %%
# HISTOGRAM

# %%
histogram_plot1= sns.histplot(data =book_final,x='fixed acidity')
histogram_plot1.set_title('Fixed acidity Histogram Plot')
# Out:
# Text(0.5, 1.0, 'Fixed acidity Histogram Plot')

# %%
histogram_plot2= sns.histplot(data =book_final,x='volatile acidity')
histogram_plot2.set_title('Volatile acidity Histogram Plot')
# Out:
# Text(0.5, 1.0, 'Volatile acidity Histogram Plot')

# %%
histogram_plot3= sns.histplot(data =book_final,x='citric acid')
histogram_plot3.set_title('Citric acid Histogram Plot')
# Out:
# Text(0.5, 1.0, 'Citric acid Histogram Plot')

# %%
histogram_plot4= sns.histplot(data =book_final,x='residual sugar')
histogram_plot4.set_title('Residual Sugar Histogram Plot')
# Out:
# Text(0.5, 1.0, 'Residual Sugar Histogram Plot')

# %%
histogram_plot5= sns.histplot(data =book_final,x='chlorides')
histogram_plot5.set_title('Chlorides Histogram Plot')
# Out:
# Text(0.5, 1.0, 'Chlorides Histogram Plot')

# %%
histogram_plot6= sns.histplot(data =book_final,x='free sulfur dioxide')
histogram_plot6.set_title('Free Sulfur Dioxide Histogram Plot')
# Out:
# Text(0.5, 1.0, 'Free Sulfur Dioxide Histogram Plot')

# %%
histogram_plot7= sns.histplot(data =book_final,x='total sulfur dioxide')
histogram_plot7.set_title('Total Sulfur Dioxide Histogram Plot')
# Out:
# Text(0.5, 1.0, 'Total Sulfur Dioxide Histogram Plot')

# %%
histogram_plot8= sns.histplot(data =book_final,x='density')
histogram_plot8.set_title('Density Histogram Plot')
# Out:
# Text(0.5, 1.0, 'Density Histogram Plot')

# %%
histogram_plot9= sns.histplot(data =book_final,x='pH')
histogram_plot9.set_title('pH Histogram Plot')
# Out:
# Text(0.5, 1.0, 'pH Histogram Plot')

# %%
histogram_plot10= sns.histplot(data =book_final,x='sulphates')
histogram_plot10.set_title('Sulphates Histogram Plot')
# Out:
# Text(0.5, 1.0, 'Sulphates Histogram Plot')

# %%
histogram_plot11= sns.histplot(data =book_final,x='alcohol')
histogram_plot11.set_title('Alcohol Histogram Plot')
# Out:
# Text(0.5, 1.0, 'Alcohol Histogram Plot')

# %%
histogram_plot12= sns.histplot(data =book_final,x='quality')
histogram_plot12.set_title('Quality Histogram Plot')
# Out:
# Text(0.5, 1.0, 'Quality Histogram Plot')

# %%
# PIE CHART

# %%
mean_1=book_final['fixed acidity'].mean()

adove_mean_count= book_final[book_final['fixed acidity']>mean_1]['fixed acidity'].count()
below_mean_count= book_final[book_final['fixed acidity']<mean_1]['fixed acidity'].count()

labels=['Greater than Mean','Less than Mean']
sizes=[adove_mean_count,below_mean_count]
colors=['yellow','green']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%',startangle=60)
plt.axis('equal')
plt.title('Fixed Acidity Greather than and Less than Mean')
plt.show()

# %%
mean_1 = book_final['volatile acidity'].mean()


above_mean_count = book_final[book_final['volatile acidity'] > mean_1]['volatile acidity'].count()
below_mean_count = book_final[book_final['volatile acidity'] < mean_1]['volatile acidity'].count()

labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['orange','purple']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Volatile Acidity Greater than and Less than Mean')
plt.show()

# %%
mean_1 = book_final['citric acid'].mean()


above_mean_count = book_final[book_final['citric acid'] > mean_1]['citric acid'].count()
below_mean_count = book_final[book_final['citric acid'] < mean_1]['citric acid'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['yellow', 'blue']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Citric Acid Greater than and Less than Mean')
plt.show()

# %%
mean_1 = book_final['residual sugar'].mean()


above_mean_count = book_final[book_final['residual sugar'] > mean_1]['residual sugar'].count()
below_mean_count = book_final[book_final['residual sugar'] < mean_1]['residual sugar'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['gold', 'red']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=180)
plt.axis('equal')
plt.title('Residual Sugar Greater than and Less than Mean')
plt.show()

# %%
mean_1 = book_final['chlorides'].mean()


above_mean_count = book_final[book_final['chlorides'] > mean_1]['chlorides'].count()
below_mean_count = book_final[book_final['chlorides'] < mean_1]['chlorides'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['silver', 'brown']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Chlorides Greater than and Less than Mean')
plt.show()

# %%
mean_1 = book_final['free sulfur dioxide'].mean()


above_mean_count = book_final[book_final['free sulfur dioxide'] > mean_1]['free sulfur dioxide'].count()
below_mean_count = book_final[book_final['free sulfur dioxide'] < mean_1]['free sulfur dioxide'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['pink', 'gray']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Free Sulfur Dioxide Greater than and Less than Mean')
plt.show()

# %%
mean_1 = book_final['total sulfur dioxide'].mean()


above_mean_count = book_final[book_final['total sulfur dioxide'] > mean_1]['total sulfur dioxide'].count()
below_mean_count = book_final[book_final['total sulfur dioxide'] < mean_1]['total sulfur dioxide'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['blue', 'violet']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=100)
plt.axis('equal')
plt.title('Total Sulfur Dioxide Greater than and Less than Mean')
plt.show()

# %%
mean_1 = book_final['density'].mean()


above_mean_count = book_final[book_final['density'] > mean_1]['density'].count()
below_mean_count = book_final[book_final['density'] < mean_1]['density'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['orange', 'brown']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Density Greater than and Less than Mean')
plt.show()

# %%
mean_1 = book_final['pH'].mean()


above_mean_count = book_final[book_final['pH'] > mean_1]['pH'].count()
below_mean_count = book_final[book_final['pH'] < mean_1]['pH'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['purple', 'lightgreen']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('pH Greater than and Less than Mean')
plt.show()

# %%
mean_1 = book_final['sulphates'].mean()


above_mean_count = book_final[book_final['sulphates'] > mean_1]['sulphates'].count()
below_mean_count = book_final[book_final['sulphates'] < mean_1]['sulphates'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['lightblue', 'gold']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Sulphates Greater than and Less than Mean')
plt.show()

# %%
mean_1 = book_final['alcohol'].mean()


above_mean_count = book_final[book_final['alcohol'] > mean_1]['alcohol'].count()
below_mean_count = book_final[book_final['alcohol'] < mean_1]['alcohol'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['gold', 'silver']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Alcohol Greater than and Less than Mean')
plt.show()

# %%
mean_1 = book_final['quality'].mean()


above_mean_count = book_final[book_final['quality'] > mean_1]['quality'].count()
below_mean_count = book_final[book_final['quality'] < mean_1]['quality'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['lightpink', 'blue']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Quality Greater than and Less than Mean')
plt.show()

# %%
book_corr=['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']
col= book_final[book_corr].corr()
col
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255557     0.670856
# volatile acidity          -0.255557          1.000000    -0.552909
# citric acid                0.670856         -0.552909     1.000000
# residual sugar             0.114595          0.001877     0.143517
# chlorides                  0.093472          0.060748     0.203981
# free sulfur dioxide       -0.152932         -0.010591    -0.061252
# total sulfur dioxide      -0.113325          0.076247     0.036014
# density                    0.667693          0.022753     0.364104
# pH                        -0.682452          0.235182    -0.542637
# sulphates                  0.182291         -0.261364     0.312839
# alcohol                   -0.061858         -0.202672     0.109925
# quality                    0.124602         -0.390787     0.226772
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
book_corr=['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']
col= book_final[book_corr].corr()
fig,ax = plt.subplots(figsize=(11, 6)) 
heatmap = sns.heatmap(col, annot=True, cmap='viridis',ax=ax)
heatmap.set_xticklabels(heatmap.get_xticklabels())
# Out:
# [Text(0.5, 0, 'fixed acidity'),
#  Text(1.5, 0, 'volatile acidity'),
#  Text(2.5, 0, 'citric acid'),
#  Text(3.5, 0, 'residual sugar'),
#  Text(4.5, 0, 'chlorides'),
#  Text(5.5, 0, 'free sulfur dioxide'),
#  Text(6.5, 0, 'total sulfur dioxide'),
#  Text(7.5, 0, 'density'),
#  Text(8.5, 0, 'pH'),
#  Text(9.5, 0, 'sulphates'),
#  Text(10.5, 0, 'alcohol'),
#  Text(11.5, 0, 'quality')]
